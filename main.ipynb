# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
DATA_DIR= '/content/gdrive/MyDrive/Colab Notebooks/yolov8/Prototip_Proje/datasets'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.5/660.5 kB 9.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/gdrive/MyDrive/Colab Notebooks/yolov8/Prototip_Proje/yolov8n-cls.pt')
results = model.train(data=DATA_DIR, epochs=100, imgsz=224)
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO('/content/runs/classify/train/weights/best.pt')

result = model('/content/gdrive/MyDrive/Colab Notebooks/yolov8/Prototip_Proje/datasets/train/Kırık/denoised_translated_57.jpg')
# Out:
# image 1/1 /content/gdrive/MyDrive/Colab Notebooks/yolov8/Prototip_Proje/datasets/train/Kırık/denoised_translated_57.jpg: 224x224 Kırık 1.00, MemeKanseri 0.00, MelomaCiltKanser 0.00, BeyinTümörü 0.00, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
